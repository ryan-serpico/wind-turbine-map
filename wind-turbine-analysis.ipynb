# %% [markdown]
# # Wind turbine analysis
#
# This notebook is a simple analysis of the wind turbine data [provided by the U.S. Geological Survey (USGS)](https://eerscmap.usgs.gov/uswtdb/data/) for the San Antonio Express-News.
#
# Questions we have for the data:
# - How many turbines currently operate across the country?
# - How many currently operate in Texas?
# - Which Texas counties have the most turbines?
# - Which wind farms are the largest in Texas?
#
# Before we do anything, let's import the libraries we'll need.

# %%
# We install pandas for data analysis
import pandas as pd

# We install itables for interactive tables
from itables import show

# %% [markdown]
# Now we import the data we collected from the USGS. Definitions of the columns are available [here](https://eerscmap.usgs.gov/uswtdb/api-doc/#keyValue) ([Web Archive](https://web.archive.org/web/20220917234036/https://eerscmap.usgs.gov/uswtdb/api-doc/)).

# %%
full_df = pd.read_csv('data/uswtdb_v5_3_20230113.csv')

show(full_df)
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="b0fdb82b-aa16-4748-a48c-cc8f35d1adaf" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#
#       <th>case_id</th>
#       <th>faa_ors</th>
#       <th>faa_asn</th>
#       <th>usgs_pr_id</th>
#       <th>eia_id</th>
#       <th>t_state</th>
#       <th>t_county</th>
#       <th>t_fips</th>
#       <th>p_name</th>
#       <th>p_year</th>
#       <th>p_tnum</th>
#       <th>p_cap</th>
#       <th>t_manu</th>
#       <th>t_model</th>
#       <th>t_cap</th>
#       <th>t_hh</th>
#       <th>t_rd</th>
#       <th>t_rsa</th>
#       <th>t_ttlh</th>
#       <th>retrofit</th>
#       <th>retrofit_year</th>
#       <th>t_conf_atr</th>
#       <th>t_conf_loc</th>
#       <th>t_img_date</th>
#       <th>t_img_srce</th>
#       <th>xlong</th>
#       <th>ylat</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[3072695, "NaN", "NaN", 5143.0, 52161.0, "CA", "Kern County", 6029, "251 Wind", 1987.0, 194, 18.43, "Vestas", "NaN", 95.0, NaN, NaN, NaN, NaN, 0, NaN, 2, 3, "5/8/2018", "Digital Globe", -118.36441, 35.077435], [3072661, "NaN", "NaN", 5149.0, 52161.0, "CA", "Kern County", 6029, "251 Wind", 1987.0, 194, 18.43, "Vestas", "NaN", 95.0, NaN, NaN, NaN, NaN, 0, NaN, 2, 3, "5/8/2018", "Digital Globe", -118.363762, 35.077908], [3072704, "NaN", "NaN", 5146.0, 52161.0, "CA", "Kern County", 6029, "251 Wind", 1987.0, 194, 18.43, "Vestas", "NaN", 95.0, NaN, NaN, NaN, NaN, 0, NaN, 2, 3, "5/8/2018", "Digital Globe", -118.364197, 35.077644], [3063269, "19-028130", "2016-WTE-5934-OE", NaN, NaN, "IA", "Story County", 19169, "30 MW Iowa DG Portfolio", 2017.0, 10, 30.0, "Nordex", "AW125/3000", 3000.0, 87.5, 125.0, 12271.85, 150.0, 0, NaN, 3, 3, "7/23/2017", "Digital Globe", -93.632835, 41.882477], [3057059, "19-027954", "2016-WTE-9485-OE", NaN, NaN, "IA", "Story County", 19169, "30 MW Iowa DG Portfolio", 2017.0, 10, 30.0, "Nordex", "AW125/3000", 3000.0, 87.5, 125.0, 12271.85, 150.0, 0, NaN, 3, 3, "5/13/2017", "Digital Globe", -93.623009, 41.88147], [3049500, "19-028030", "2014-WTE-4080-OE", NaN, NaN, "IA", "Story County", 19169, "30 MW Iowa DG Portfolio", 2017.0, 10, 30.0
# %% [markdown]
# Alright, there are 72,669 turbines operating across the country. Let's see how many are in each state.
#
# I'm importing an additional dataframe that contains the full names of states to merge into our pivot table for readability.

# %%
state_abbrev_df = pd.read_csv('data/state_abbreviations.csv')

# Create a pivot_table that counts the number of case_ids for each t_state. We also sort the values in descending order.
state_t_count_df = pd.pivot_table(full_df, values='case_id', index=['t_state'], aggfunc='count').sort_values(by='case_id', ascending=False)

# Merge the state_t_count_df with the state_abbrev_df, just to improve readability.
state_t_count_df = pd.merge(state_t_count_df, state_abbrev_df, left_on='t_state', right_on='abbreviations')

# We don't need the abbreviations column anymore, so we drop it.
state_t_count_df = state_t_count_df.drop(columns=['abbreviations'])

# Here I'm renaming the columns, again just to improve readability..
state_t_count_df = state_t_count_df.rename(columns={'t_state': 'State', 'case_id': 'Turbine count'})

# Here I'm defining the names of the columns.
state_t_count_df.columns = ['Turbine count', 'State']

# Reorder the columns
state_t_count_df = state_t_count_df[['State', 'Turbine count']]

# Show the pivot_table
show(state_t_count_df)
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="1c642527-c4cd-4bad-9c3e-de9a9a177a96" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Turbine count</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[0, "Texas ", 18586], [1, "Iowa ", 6220], [2, "California ", 5974], [3, "Oklahoma ", 5487], [4, "Kansas ", 3962], [5, "Illinois ", 3551], [6, "Colorado ", 2834], [7, "Minnesota ", 2687], [8, "North Dakota ", 2134], [9, "Oregon ", 2120], [10, "New Mexico ", 1952], [11, "Washington ", 1826], [12, "Michigan ", 1631], [13, "Indiana ", 1614], [14, "Nebraska ", 1541], [15, "Wyoming ", 1456], [16, "South Dakota ", 1411], [17, "New York ", 1231], [18, "Missouri ", 1174], [19, "Montana ", 803], [20, "Pennsylvania ", 751], [21, "Idaho ", 541], [22, "Ohio ", 499], [23, "Wisconsin ", 451], [24, "West Virginia ", 419], [25, "Maine ", 417], [26, "Arizona ", 286], [27, "Utah ", 208], [28, "Alaska ", 142], [29, "Hawaii ", 129], [30, "North Carolina ", 105], [31, "Massachusetts ", 92], [32, "New Hampshire ", 84], [33, "Maryland ", 80], [34, "Vermont ", 73], [35, "Nevada ", 68], [36, "Puerto Rico ", 63], [37, "Rhode Island ", 35], [38, "Tennessee ", 18], [39, "New Jersey ", 6], [40, "Connecticut ", 3], [41, "Virginia ", 2], [42, "Delaware ", 1], [43, "Arkansas ", 1], [44, "Guam ", 1]];
#
#     // Define the dt_args
#     let dt_args = {"order": []};
#     dt_args["data"] = data;
#
#     $(document).ready(function () {
#
#         $('#1c642527-c4cd-4bad-9c3e-de9a9a177a96').DataTable(dt_args);
#     });
# </script>
# </div>

# %% [markdown]
# Alright, Texas has more wind turbines than any other state and it's not close.
#
# Texas has more than three times as many turbines as California, which is third.
#
# Now let's isolate the turbines in Texas and see which counties have the most.

# %%
# Let's create a new dataframe with turbines in the state of Texas. The column we filter is 't_state'
texas_df = full_df[full_df['t_state'] == 'TX']

show(texas_df)

# I'm interested in creating an animated map in Flourish of all the Texas wind turbines coming online. I can't have any rows with missing values in the 'p_year' column, so I'm filtering those out.
animated_map_df = texas_df[texas_df['p_year'].notna()]

# Convert p_year to datetime
animated_map_df['p_year'] = pd.to_datetime(animated_map_df['p_year'], format='%Y')

# Here I'm exporting the data to a csv file, so I can use it in Flourish.
animated_map_df.to_csv('output/texas_wind_turbines.csv', index=False)
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="2acf36a8-cd32-4a96-8739-677377a0daa1" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>case_id</th>
#       <th>faa_ors</th>
#       <th>faa_asn</th>
#       <th>usgs_pr_id</th>
#       <th>eia_id</th>
#       <th>t_state</th>
#       <th>t_county</th>
#       <th>t_fips</th>
#       <th>p_name</th>
#       <th>p_year</th>
#       <th>p_tnum</th>
#       <th>p_cap</th>
#       <th>t_manu</th>
#       <th>t_model</th>
#       <th>t_cap</th>
#       <th>t_hh</th>
#       <th>t_rd</th>
#       <th>t_rsa</th>
#       <th>t_ttlh</th>
#       <th>retrofit</th>
#       <th>retrofit_year</th>
#       <th>t_conf_atr</th>
#       <th>t_conf_loc</th>
#       <th>t_img_date</th>
#       <th>t_img_srce</th>
#       <th>xlong</th>
#       <th>ylat</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[804, 3108495, "48-178030", "2019-WTW-9764-OE", NaN, 62142.0, "TX", "Stonewall County", 48433, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE2.82-127", 2820.0, 89.0, 127.0, 12667.69, 152.4, 0, NaN, 3, 3, "1/28/2021", "Digital Globe", -100.515167, 33.012295], [805, 3106421, "48-176243", "2019-WTW-5096-OE", NaN, 62142.0, "TX", "Fisher County", 48151, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE1.79-100", 1790.0, 80.0, 100.0, 7853.98, 130.1, 0, NaN, 3, 3, "10/31/2020", "Digital Globe", -100.588982, 32.882858], [806, 3107777, "48-178003", "2019-WTW-5139-OE", NaN, 62142.0, "TX", "Kent County", 48263, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE2.82-127", 2820.0, 89.0, 127.0, 12667.69, 152.4, 0, NaN, 3, 3, "1/28/2021", "Digital Globe", -100.551399, 33.02129], [807, 3106744, "48-176000", "2019-WTW-5110-OE", NaN, 62142.0, "TX", "Fisher County", 48151, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE1.79-100", 1790.0, 80.0, 100.0, 7853.98, 130.1, 0, NaN, 3, 3, "10/31/2020", "Digital Globe", -100.57402, 32.903206], [808, 3108501, "48-175998", "2019-WTW-5114-OE", NaN, 62142.0, "TX", "Fisher County", 48151, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE2.82-127", 2820.0, 89.0, 127.0, 12667.69, 152.4, 0, NaN, 3, 3, "10/31/2020", "Digital Globe", -100.564224, 32.910919], [809, 3105824, "48-176228", "2019-WTW-5095-OE", NaN, 62142.0, "TX", "Fisher County", 48151, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE1.79-100", 1790.0, 80.0, 100.0, 7853.98, 130.1, 0, NaN, 3, 3, "10/31/2020", "Digital Globe", -100.593864, 32.886856], [810, 3109559, "48-178634", "2019-WTW-5161-OE", NaN, 62142.0, "TX", "Kent County", 48263, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE2.82-127", 2820.0, 89.0, 127.0, 12667.69, 152.4, 0, NaN, 3, 3, "2/2/2022", "Digital Globe", -100.5438, 33.05064], [811, 3109360, "48-178224", "2019-WTW-9768-OE", NaN, 62142.0, "TX", "Stonewall County", 48433, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE2.82-127", 2820.0, 89.0, 127.0, 12667.69, 152.4, 0, NaN, 3, 3, "1/28/2021", "Digital Globe", -100.499001, 33.001842], [812, 3109923, "48-178208", "2019-WTW-5135-OE", NaN, 62142.0, "TX", "Kent County", 48263, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE2.82-127", 2820.0, 89.0, 127.0, 12667.69, 152.4, 0, NaN, 3, 3, "1/28/2021", "Digital Globe", -100.572586, 33.007259], [813, 3106328, "48-176317", "2019-WTW-5174-OE", NaN, 62142.0, "TX", "Kent County", 48263, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE2.82-127", 2820.0, 89.0, 127.0, 12667.69, 152.4, 0, NaN, 3, 3, "2/2/2022", "Digital Globe", -100.527443, 33.070862], [814, 3106153, "48-176271", "2019-WTW-5105-OE", NaN, 62142.0, "TX", "Fisher County", 48151, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE1.79-100", 1790.0, 80.0, 100.0, 7853.98, 130.1, 0, NaN, 3, 3, "10/31/2020", "Digital Globe", -100.560303, 32.89323], [815, 3105947, "48-177892", "2019-WTW-5147-OE", NaN, 62142.0, "TX", "Kent County", 48263, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE2.82-127", 2820.0, 89.0, 127.0, 12667.69, 152.4, 0, NaN, 3, 3, "1/28/2021", "Digital Globe", -100.519203, 33.021446], [816, 3106168, "48-176801", "2019-WTW-5158-OE", NaN, 62142.0, "TX", "Stonewall County", 48433, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE2.82-127", 2820.0, 89.0, 127.0, 12667.69, 152.4, 0, NaN, 3, 3, "2/2/2022", "Digital Globe", -100.502502, 33.040592], [817, 3106620, "48-176999", "2019-WTW-5145-OE", NaN, 62142.0, "TX", "Kent County", 48263, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE2.82-127", 2820.0, 89.0, 127.0, 12667.69, 152.4, 0, NaN, 3, 3, "1/28/2021", "Digital Globe", -100.533516, 33.025146], [818, 3107778, "48-176902", "2019-WTW-5128-OE", NaN, 62142.0, "TX", "Kent County", 48263, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE2.82-127", 2820.0, 89.0, 127.0, 12667.69, 152.4, 0, NaN, 3, 3, "10/31/2020", "Digital Globe", -100.562759, 32.995575], [819, 3108449, "48-176658", "2019-WTW-5120-OE", NaN, 62142.0, "TX", "Kent County", 48263, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE2.82-127", 2820.0, 89.0, 127.0, 12 ...
# /var/folders/w4/djgt59l94t51k1198f2hnn980000gn/T/ipykernel_12551/3422785734.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   animated_map_df['p_year'] = pd.to_datetime(animated_map_df['p_year'], format='%Y')

# %% [markdown]
# When it comes to finding the largest wind farms, we have a few options. We could look at the area covered by the turbines, the number of turbines, or the total capacity of the turbines.
#
# For this analysis I'm going to focus on the number of turbines. [The story](https://www.expressnews.com/news/texas/article/new-wind-turbines-west-texas-17822375.php) that inspired this quick-turn project was about the visual clutter wind turbines can create — not their total electrical generation capacity.
#
# First let's find the Texas counties with the most turbines.

# %%
# We create a pivot table that counts every wind turbine in each county. There is a unique case_id for each turbine. We sort the values in descending order.
turbine_county_count = pd.pivot_table(texas_df, values='case_id', index=['t_county'], aggfunc='count').sort_values(by='case_id', ascending=False)

# Reset the index
turbine_county_count = turbine_county_count.reset_index()

# Rename the columns
turbine_county_count = turbine_county_count.rename(columns={'t_county': 'County', 'case_id': 'Turbine count'})

# For each value in the County column, do a find and replace to remove the word "County". We do this so that Datawrapper understands the county names.
turbine_county_count['County'] = turbine_county_count['County'].str.replace(' County', '')

# Export the data to a csv file
turbine_county_count.to_csv('output/turbine_county_count.csv', index=False)

show(turbine_county_count)
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="e7aa574d-083e-40ac-87eb-e20d7ed886ea" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#
#       <th>County</th>
#       <th>Turbine count</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [["Nolan", 1411], ["Willacy", 660], ["Scurry", 649], ["Sterling", 632], ["Carson", 620], ["Pecos", 582], ["Glasscock", 469], ["Borden", 462], ["Kenedy", 454], ["Webb", 450], ["Floyd", 441], ["Hansford", 432], ["San Patricio", 428], ["Starr", 419], ["Oldham", 418], ["Upton", 373], ["Taylor", 370], ["Crockett", 369], ["Wilbarger", 361], ["Lynn", 318], ["Coke", 316], ["Castro", 282], ["Knox", 276], ["Mills", 269], ["Haskell", 265], ["Cameron", 258], ["Fisher", 254], ["Shackelford", 245], ["Hale", 239], ["Young", 222], ["Howard", 219], ["Mitchell", 206], ["Archer", 188], ["Cooke", 179], ["Jack", 177], ["Throckmorton", 177], ["Concho", 170], ["Irion", 163], ["Deaf Smith", 162], ["Callahan", 158], ["Nueces", 150], ["Limestone", 148], ["Foard", 139], ["Bee", 137], ["McCulloch", 128], ["Ochiltree", 123], ["Briscoe", 123], ["Crosby", 120], ["Clay", 119], ["Baylor", 116], ["Dawson", 111], ["Hidalgo", 111], ["Zapata", 110], ["Refugio", 108], ["Reagan", 105], ["Hardeman", 103], ["Dickens", 100], ["Comanche", 99], ["Parmer", 96], ["Roberts", 95], ["Schleicher", 92], ["Winkler", 87], ["Martin", 80], ["Moore", 72], ["Randall", 71], ["Gray", 69], ["Val Verde", 69], ["Garza", 67], ["Cochran", 67], ["Donley", 63], ["Hemphill", 61], ["Kent", 58], ["Andrews", 57], ["Tom Green", 56], ["Kinney", 55], ["Duval", 53], ["Matagorda", 48], ["Hill", 46], ["Navarro", 42], ["Erath", 37], ["Bailey", 35], ["Jim Hogg", 35], ["Armstrong", 34], ["Sherman", 26], ["Lubbock", 20], ["Stonewall", 18], ["Eastland", 17], ["McLennan", 14], ["Hutchinson", 10], ["Ector", 9], ["Lampasas", 9], ["Lamb", 8], ["Potter", 5], ["Denton", 3], ["Collin", 2], ["El Paso", 2], ["Hartley", 2], ["Brown", 1], ["Gaines", 1], ["Ellis", 1]];
#
#     // Define the dt_args
#     let dt_args = {"order": []};
#     dt_args["data"] = data;
#
#     $(document).ready(function () {
#
#         $('#e7aa574d-083e-40ac-87eb-e20d7ed886ea').DataTable(dt_args);
#     });
# </script>
# </div>

# %% [markdown]
# There's a clear winner here. Nolan County has 1,411 turbines, which is more than double the next county.
#
# Now let's find which wind farms have the most turbines. I'm also going to merge in the county names to make it easier for me to see whether any come from Nolan County.

# %%
# Create a pivot_table that shows the number of turbines per p_name (which is the name of the wind project)
wind_farm_t_count_pivot = pd.pivot_table(texas_df, values='case_id', index=['p_name'], aggfunc='count').sort_values(by='case_id', ascending=False)

# We don't want any wind projects with "unknown" in the name
wind_farm_t_count_pivot = wind_farm_t_count_pivot[~wind_farm_t_count_pivot.index.str.contains('unknown', case=False)]

# Rename wind_farm_t_count_pivot case_id column to turbine_count
wind_farm_t_count_pivot = wind_farm_t_count_pivot.rename(columns={'case_id': 'turbine_count'})

# Create a new dataframe that dedupes the texas_df dataframe by p_name
deduped_texas_df = texas_df.drop_duplicates(subset=['p_name'])

# Merge the deduped_texas_df with the wind_farm_t_count_pivot
wind_farm_t_count_pivot = pd.merge(deduped_texas_df, wind_farm_t_count_pivot, left_on='p_name', right_on='p_name').sort_values(by='turbine_count', ascending=False)

# Drop everything but p_name, turbine_count and t_county
wind_farm_t_count_pivot = wind_farm_t_count_pivot[['p_name', 'turbine_count', 't_county']]

# Reset the index
wind_farm_t_count_pivot = wind_farm_t_count_pivot.reset_index(drop=True)

# Rename p_name to Wind Farm, turbine_count to Turbine Count, and t_county to County
wind_farm_t_count_pivot = wind_farm_t_count_pivot.rename(columns={'p_name': 'Wind Farm', 'turbine_count': 'Turbine Count', 't_county': 'County'})

# Reorder the columns
wind_farm_t_count_pivot = wind_farm_t_count_pivot[['Wind Farm', 'County', 'Turbine Count']]

show(wind_farm_t_count_pivot)
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="6d53187e-840b-427f-8950-5158904f176b" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#
#       <th>Wind Farm</th>
#       <th>County</th>
#       <th>Turbine Count</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [
ning Spur 2", "Oldham County", 87], ["Papalote Creek II", "San Patricio County", 87], ["Camp Springs", "Scurry County", 87], ["Los Vientos I", "Willacy County", 87], ["Logan's Gap Wind", "Comanche County", 87], ["Goldthwaite", "Mills County", 86], ["Blue Summit", "Wilbarger County", 85], ["Penescal", "Kenedy County", 84], ["Penescal II", "Kenedy County", 84], ["Canadian Breaks", "Oldham County", 84], ["Los Vientos II", " ...

# %%
# Filter texas_df to only include turbines on "Firewheel Wind" us the p_name column
firewheel_wind_df = texas_df[texas_df['p_name'] == 'Firewheel Wind']

show(firewheel_wind_df)

firewheel_wind_df.to_csv('output/firewheel_wind_turbines.csv', index=False)
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="0be1af50-0715-4750-b9df-aaec29acf806" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>case_id</th>
#       <th>faa_ors</th>
#       <th>faa_asn</th>
#       <th>usgs_pr_id</th>
#       <th>eia_id</th>
#       <th>t_state</th>
#       <th>t_county</th>
#       <th>t_fips</th>
#       <th>p_name</th>
#       <th>p_year</th>
#       <th>p_tnum</th>
#       <th>p_cap</th>
#       <th>t_manu</th>
#       <th>t_model</th>
#       <th>t_cap</th>
#       <th>t_hh</th>
#       <th>t_rd</th>
#       <th>t_rsa</th>
#       <th>t_ttlh</th>
#       <th>retrofit</th>
#       <th>retrofit_year</th>
#       <th>t_conf_atr</th>
#       <th>t_conf_loc</th>
#       <th>t_img_date</th>
#       <th>t_img_srce</th>
#       <th>xlong</th>
#       <th>ylat</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[19448, 3123442, "48-194007", "2021-WTW-4861-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 3, "8/29/2022", "Digital Globe", -101.452225, 36.321106], [19449, 3124141, "48-192889", "2021-WTW-4765-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 3, "10/3/2022", "Digital Globe", -101.457855, 36.285931], [19450, 3124063, "48-193230", "2021-WTW-4813-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 3, "10/3/2022", "Digital Globe", -101.485802, 36.359554], [19451, 3123845, "48-193227", "2021-WTW-4703-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 3, "9/4/2022", "Digital Globe", -101.521706, 36.359604], [19452, 3123571, "48-194002", "2021-WTW-4843-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 3, "8/29/2022", "Digital Globe", -101.392006, 36.343418], [19453, 3123986, "48-193151", "2021-WTW-4797-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 3, "10/3/2022", "Digital Globe", -101.504112, 36.386364], [19454, 3124991, "NaN", "2021-WTW-4616-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 3, "9/4/2022", "Digital Globe", -101.583389, 36.428116], [19455, 3123598, "48-192874", "2021-WTW-4699-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 3, "9/4/2022", "Digital Globe", -101.51194, 36.368382], [19456, 3125458, "NaN", "2021-WTW-4789-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 3, "8/29/2022", "Digital Globe", -101.391563, 36.431526], [19457, 3123539, "48-194037", "2021-WTW-4827-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 3, "8/29/2022", "Digital Globe", -101.393234, 36.355911], [19458, 3123242, "48-192877", "2021-WTW-4710-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 3, "9/4/2022", "Digital Globe", -101.534607, 36.338547], [19459, 3124670, "NaN", "2021-WTW-4784-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 3, "8/29/2022", "Digital Globe", -101.401375, 36.450577], [19460, 3123793, "48-194006", "2021-WTW-4860-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 3, "10/3/2022", "Digital Globe", -101.457787, 36.326057], [19461, 3125207, "NaN", "2021-WTW-4787-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 3, "8/29/2022", "Digital Globe", -101.403542, 36.434296], [19462, 3123653, "48-192880", "2021-WTW-4714-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 3, "9/4/2022", "Digital Globe", -101.561127, 36.335018], [19463, 3124877, "NaN", "2021-WTW-4645-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 1, "2/17/2022", "Digital Globe", -101.594139, 36.432514], [19464, 3123396, "48-194682", "2021-WTW-4687-OE", NaN, NaN, "TX", "Hansford County", 48195, "Firewheel Wind", 2022.0, 286, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN, 0, NaN, 1, 1, "2/17/2022", "Digital Globe", -101.59404, 36.374088], [19465, ...

# %% [markdown]
# So the wind project in Texas with the most turbines is Firewheel Wind out in Hansford County. We need to make sure that these are all operational — or maybe not. Maybe its OK that these are just planned.

# %% [markdown]
# Let's find the first record for each project so that we can map out specific locations.

# %%
# For each wind farm, only keep the first row. This will remove duplicate wind farms.
single_point_df = texas_df.drop_duplicates(subset='p_name', keep='first')

# Filter out "unknown" wind farms
single_point_df = single_point_df[~single_point_df['p_name'].str.contains('unknown', case=False)]

show(single_point_df)

single_point_df.to_csv('output/texas_wind_farm_tnum.csv', index=False)
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="c1a4e5d4-a44d-47b8-aa72-8994d3689742" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>case_id</th>
#       <th>faa_ors</th>
#       <th>faa_asn</th>
#       <th>usgs_pr_id</th>
#       <th>eia_id</th>
#       <th>t_state</th>
#       <th>t_county</th>
#       <th>t_fips</th>
#       <th>p_name</th>
#       <th>p_year</th>
#       <th>p_tnum</th>
#       <th>p_cap</th>
#       <th>t_manu</th>
#       <th>t_model</th>
#       <th>t_cap</th>
#       <th>t_hh</th>
#       <th>t_rd</th>
#       <th>t_rsa</th>
#       <th>t_ttlh</th>
#       <th>retrofit</th>
#       <th>retrofit_year</th>
#       <th>t_conf_atr</th>
#       <th>t_conf_loc</th>
#       <th>t_img_date</th>
#       <th>t_img_srce</th>
#       <th>xlong</th>
#       <th>ylat</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[804, 3108495, "48-178030", "2019-WTW-9764-OE", NaN, 62142.0, "TX", "Stonewall County", 48433, "Amadeus", 2020.0, 96, 250.12, "GE Wind", "GE2.82-127", 2820.0, 89.0, 127.0, 12667.69, 152.4, 0, NaN, 3, 3, "1/28/2021", "Digital Globe", -100.515167, 33.012295], [965, 3061611, "48-037361", "2016-WTW-4522-OE", NaN, 60902.0, "TX", "Scurry County", 48415, "Amazon Wind Farm Texas", 2017.0, 110, 253.0, "GE Wind", "GE2.3-116", 2300.0, 80.0, 116.0, 10568.32, 138.1, 0, NaN, 3, 3, "5/19/2017", "Digital Globe", -100.982384, 32.875961], [1227, 3027324, "48-015121", "2008-ASW-3196-OE", 40263.0, NaN, "TX", "Lubbock County", 48303, "American Windmill Museum", 2005.0, 1, 0.66, "Vestas", "V47-0.66", 660.0, 50.0, 47.0, 1734.94, 73.5, 0, NaN, 3, 3, "9/3/2020", "Digital Globe", -101.823891, 33.580894], [1228, 3044268, "48-030848", "2012-WTW-5050-OE", 42861.0, 58000.0, "TX", "Kinney County", 48271, "Anacacho", 2012.0, 55, 99.0, "Vestas", "V100-1.8", 1800.0, 80.0, 100.0, 7853.98, 130.1, 0, NaN, 3, 3, "11/17/2020", "Digital Globe", -100.208794, 29.182295], [1302, 3036080, "48-026242", "2010-WTW-13447-OE", 41378.0, NaN, "TX", "Denton County", 48121, "Apogee Stadium Wind", 2012.0, 3, 0.3, "Northern Power Systems", "NW100", 100.0, 37.0, 21.0, 346.36, 47.5, 0, NaN, 3, 3, "1/1/2012", "NAIP", -97.160889, 33.202095], [1306, 3123619, "48-191287", "2021-WTW-4119-OE", NaN, NaN, "TX", "Upton County", 48461, "Appaloosa Run", 2022.0, 56, NaN, "NaN", "NaN", NaN, NaN, NaN, NaN, NaN